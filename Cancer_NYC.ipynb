# %% [markdown]
# <a href="https://colab.research.google.com/github/johanaluna/Cancer_DataSet/blob/master/Cancer_NYC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The data was extracted from https://wonder.cdc.gov/cancer.html
#
# A cancer incidence rate is the number of new cancers of a specific site/type occurring in a specified population during a year, usually expressed as the number of cancers per 100,000 population at risk.

# %%
# import plotly.express as px
# !pip uninstall plotly
# Out:
# Uninstalling plotly-3.6.1:
#   Would remove:
#     /usr/local/etc/jupyter/nbconfig/notebook.d/plotlywidget.json
#     /usr/local/lib/python3.6/dist-packages/_plotly_utils/*
#     /usr/local/lib/python3.6/dist-packages/plotly-3.6.1.dist-info/*
#     /usr/local/lib/python3.6/dist-packages/plotly/*
#     /usr/local/lib/python3.6/dist-packages/plotlywidget/*
#     /usr/local/share/jupyter/nbextensions/plotlywidget/extension.js
#     /usr/local/share/jupyter/nbextensions/plotlywidget/index.js
#     /usr/local/share/jupyter/nbextensions/plotlywidget/index.js.map
# Proceed (y/n)? y
#   Successfully uninstalled plotly-3.6.1

# %%
pip install plotly --upgrade
# Out:
# ...
#      |████████████████████████████████| 7.1MB 24kB/s
# ...

# %%
import plotly.express as px

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # USA Incidence of Cancer

# %%
#Upload Data United States Generalized
usa1='https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/Incidence_USA.txt'#Incidennce Cancer USA
#Create DataFrame
usa_inc=pd.read_csv(usa1 , sep='"',)
usa_inc.head() #Show Data
# Out:
#   Notes\t    Year  \t  Year Code    \tCount
# 0      \t  1999.0  \t     1999.0  1330622.0
# 1      \t  2000.0  \t     2000.0  1359344.0
# 2      \t  2001.0  \t     2001.0  1418934.0
# 3      \t  2002.0  \t     2002.0  1436779.0
# 4      \t  2003.0  \t     2003.0  1450998.0

# %%
#show las rows dataframe 
usa_inc.tail
# Out:
# <bound method NDFrame.tail of                                               Notes\t  ...    \tCount
# 0                                                  \t  ...  1330622.0
# 1                                                  \t  ...  1359344.0
# 2                                                  \t  ...  1418934.0
# 3                                                  \t  ...  1436779.0
# 4                                                  \t  ...  1450998.0
# 5                                                  \t  ...  1474587.0
# 6                                                  \t  ...  1515494.0
# 7                                                  \t  ...  1553160.0
# 8                                                  \t  ...  1601920.0
# 9                                                  \t  ...  1624224.0
# 10                                                 \t  ...  1644603.0
# 11                                                 \t  ...  1635592.0
# ...

# %%
## drop the last 28 lines
nlines=len(usa_inc)-(usa_inc['Notes\t'].values == '---').argmax()
usa_inc.drop(usa_inc.tail(nlines).index,inplace=True)
usa_inc.tail
# Out:
# <bound method NDFrame.tail of    Notes\t    Year  \t  Year Code    \tCount
# 0       \t  1999.0  \t     1999.0  1330622.0
# 1       \t  2000.0  \t     2000.0  1359344.0
# 2       \t  2001.0  \t     2001.0  1418934.0
# 3       \t  2002.0  \t     2002.0  1436779.0
# 4       \t  2003.0  \t     2003.0  1450998.0
# 5       \t  2004.0  \t     2004.0  1474587.0
# 6       \t  2005.0  \t     2005.0  1515494.0
# 7       \t  2006.0  \t     2006.0  1553160.0
# 8       \t  2007.0  \t     2007.0  1601920.0
# 9       \t  2008.0  \t     2008.0  1624224.0
# 10      \t  2009.0  \t     2009.0  1644603.0
# 11      \t  2010.0  \t     2010.0  1635592.0
# 12      \t  2011.0  \t     2011.0  1666264.0
# 13      \t  2012.0  \t     2012.0  1657775.0
# 14      \t  2013.0  \t     2013.0  1680094.0
# 15      \t  2014.0  \t     2014.0  1695670.0
# 16      \t  2015.0  \t     2015.0  1707135.0>

# %%
list(usa_inc.columns) #lis the names of the columns
# Out:
# ['Notes\t', 'Year', '\t', 'Year Code', '\tCount']

# %%
usa_inc=usa_inc.drop('\t',axis=1)
usa_inc.replace('\t', '') #Remove \t characters
usa_inc.columns = ['Notes', 'Year', 'Year Code', 'Count']#rename the columns

# %%
# usa_inc['Year']=usa_inc['Year'].astype(int)#Change column year to int 
# usa_inc['Year Code']=usa_inc['Year Code'].astype(int)
pd.options.display.float_format = '{:,.0f}'.format #change the fotmat of my values in thousands with commas 
usa_inc.describe()
# Out:
#        Year  Year Code     Count
# count    17         17        17
# mean  2,007      2,007 1,556,070
# std       5          5   123,234
# min   1,999      1,999 1,330,622
# 25%   2,003      2,003 1,450,998
# 50%   2,007      2,007 1,601,920
# 75%   2,011      2,011 1,657,775
# max   2,015      2,015 1,707,135

# %%
fig, ax = plt.subplots(figsize=(8, 5)) 
g=sns.lineplot(data=usa_inc, x='Year',y='Count',palette="tab10", linewidth=2.5,ax=ax,)
g.set(ylim = (1350000,1750000))
ylabels = ['{:,.2f}'.format(y) + 'M' for y in g.get_yticks()/1000000]
g.set_yticklabels(ylabels)
plt.show();

# %%
usa_inc.head(20)
# Out:
#    Notes  Year  Year Code     Count
# 0     \t 1,999      1,999 1,330,622
# 1     \t 2,000      2,000 1,359,344
# 2     \t 2,001      2,001 1,418,934
# 3     \t 2,002      2,002 1,436,779
# 4     \t 2,003      2,003 1,450,998
# 5     \t 2,004      2,004 1,474,587
# 6     \t 2,005      2,005 1,515,494
# 7     \t 2,006      2,006 1,553,160
# 8     \t 2,007      2,007 1,601,920
# 9     \t 2,008      2,008 1,624,224
# 10    \t 2,009      2,009 1,644,603
# 11    \t 2,010      2,010 1,635,592
# 12    \t 2,011      2,011 1,666,264
# 13    \t 2,012      2,012 1,657,775
# 14    \t 2,013      2,013 1,680,094
# 15    \t 2,014      2,014 1,695,670
# 16    \t 2,015      2,015 1,707,135

# %%
fig = go.Figure()
fig.add_trace(go.Scatter( x=usa_inc['Year'],y=usa_inc['Count'],fill='tozeroy'))
fig.update_layout(title='Cancer Incidence in  United States',
                   xaxis_title='Years',
                   yaxis_title='Incidence of Cancer (# of people)',annotations=[
        go.layout.Annotation(
            x=1999,
            y=1330600,
            xref="x",
            yref="y",
            text="1999,(1.33M)",
            showarrow=True,
            arrowhead=7,
            ax=50,
            ay=10 ,font=dict(
                color="black",
                size=12)
            ),
            go.layout.Annotation(
            x=2015,
            y=1707100,
            xref="x",
            yref="y",
            text="2015,(1.70M)",
            showarrow=True,
            arrowhead=7,
            ax=30,
            ay=20 ,font=dict(
                color="black",
                size=12)
            )])

fig.update_yaxes(range=[700000, 2000000])
fig.update_xaxes(range=[1999, 2015],nticks=10)
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f7760f5e-bc03-46a5-9dec-85d8e41758e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f7760f5e-bc03-46a5-9dec-85d8e41758e5")) {
#                     Plotly.newPlot(
#                         'f7760f5e-bc03-46a5-9dec-85d8e41758e5',
# ...

# %%
# df.loc[df['AcctNum'] == '0003']['AcctValue'].values[0]

usa_1999=usa_inc.loc[usa_inc['Year']==1999]['Count']
usa_2015=usa_inc[usa_inc['Year']==2015]['Count']
rate_usa= (usa_2015.values[0]-usa_1999.values[0])/usa_1999.values[0]
rate_usa

# %% [markdown]
# # USA Incindence of Cancer by States

# %%
usa2='https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/Incidence_USA_statesPR.txt'#Incidence Cancer USA by states
usa_states=pd.read_csv(usa2, sep='"')
usa_states.head()
# Out:
#   Notes\t  Year  \t  ...  \t.2 States and Puerto Rico Code \tCount
# 0      \t 1,999  \t  ...    \t                           1  19,891
# 1      \t 1,999  \t  ...    \t                           2   2,043
# 2      \t 1,999  \t  ...    \t                           4  21,878
# 3      \t 1,999  \t  ...    \t                           6 140,586
# 4      \t 1,999  \t  ...    \t                           8  16,711
#
# [5 rows x 9 columns]

# %%
usa_states.tail
# Out:
# <bound method NDFrame.tail of                                                Notes\t  ...  \tCount
# 0                                                   \t  ...   19,891
# 1                                                   \t  ...    2,043
# 2                                                   \t  ...   21,878
# 3                                                   \t  ...  140,586
# 4                                                   \t  ...   16,711
# 5                                                   \t  ...   19,445
# 6                                                   \t  ...    4,128
# 7                                                   \t  ...    3,075
# 8                                                   \t  ...  102,797
# 9                                                   \t  ...   31,248
# 10                                                  \t  ...    5,600
# 11                                                  \t  ...    5,371
# ...

# %%
#drop last lines
#Return the row in wich it finds for the first time th character --- 
#usa_states['Notes\t'].values=='---').argmax() 
#Second. nlines is the number of lines that has information that we don't need that was in the botton of my txt file 
nlines= len(usa_states)-(usa_states['Notes\t'].values=='---').argmax() 
usa_states.drop(usa_states.tail(nlines).index,inplace=True)
usa_states.tail
# Out:
# <bound method NDFrame.tail of     Notes\t  Year  \t  ...  \t.2 States and Puerto Rico Code \tCount
# 0        \t 1,999  \t  ...    \t                           1  19,891
# 1        \t 1,999  \t  ...    \t                           2   2,043
# 2        \t 1,999  \t  ...    \t                           4  21,878
# 3        \t 1,999  \t  ...    \t                           6 140,586
# 4        \t 1,999  \t  ...    \t                           8  16,711
# 5        \t 1,999  \t  ...    \t                           9  19,445
# 6        \t 1,999  \t  ...    \t                          10   4,128
# 7        \t 1,999  \t  ...    \t                          11   3,075
# 8        \t 1,999  \t  ...    \t                          12 102,797
# 9        \t 1,999  \t  ...    \t                          13  31,248
# 10       \t 1,999  \t  ...    \t                          15   5,600
# 11       \t 1,999  \t  ...    \t                          16   5,371
# ...

# %%
list(usa_states.columns)
# Out:
# ['Notes\t',
#  'Year',
#  '\t',
#  'Year Code',
#  '\t.1',
#  'States and Puerto Rico',
#  '\t.2',
#  'States and Puerto Rico Code',
#  '\tCount']

# %%
usa_states.replace('\t', '') #Remove \t characters 
usa_states=usa_states.drop(['\t','\t.1','\t.2',],axis=1)
usa_states.columns = ['Notes', 'Year', 'Year Code', 'States and Puerto Rico','States and Puerto Rico Code','Count']

# %%
usa_states.tail# chachk last columns
# Out:
# <bound method NDFrame.tail of     Notes  Year  ...  States and Puerto Rico Code   Count
# 0      \t 1,999  ...                            1  19,891
# 1      \t 1,999  ...                            2   2,043
# 2      \t 1,999  ...                            4  21,878
# 3      \t 1,999  ...                            6 140,586
# 4      \t 1,999  ...                            8  16,711
# 5      \t 1,999  ...                            9  19,445
# 6      \t 1,999  ...                           10   4,128
# 7      \t 1,999  ...                           11   3,075
# 8      \t 1,999  ...                           12 102,797
# 9      \t 1,999  ...                           13  31,248
# 10     \t 1,999  ...                           15   5,600
# 11     \t 1,999  ...                           16   5,371
# 12     \t 1,999  ...                           17  60,589
# 13     \t 1,999  ...                           18  28,236
# 14     \t 1,999  ...                           19  16,243
# ...

# %%
pd.options.display.float_format = '{:,.0f}'.format #change format
usa_states.describe()
# Out:
#        Year  Year Code  States and Puerto Rico Code   Count
# count   870        870                          870     870
# mean  2,007      2,007                           30  30,406
# std       5          5                           16  32,054
# min   1,999      1,999                            1   2,043
# 25%   2,003      2,003                           16   8,369
# 50%   2,007      2,007                           29  21,480
# 75%   2,011      2,011                           42  35,900
# max   2,015      2,015                           72 172,776

# %%
usa_states.replace('\t', '') # change values tab to nothing
usa_states.head()
# Out:
#   Notes  Year  ...  States and Puerto Rico Code   Count
# 0    \t 1,999  ...                            1  19,891
# 1    \t 1,999  ...                            2   2,043
# 2    \t 1,999  ...                            4  21,878
# 3    \t 1,999  ...                            6 140,586
# 4    \t 1,999  ...                            8  16,711
#
# [5 rows x 6 columns]

# %%
list(usa_states['States and Puerto Rico'].unique()) #list unique values
# Out:
# ['Alabama',
#  'Alaska',
#  'Arizona',
#  'California',
#  'Colorado',
#  'Connecticut',
#  'Delaware',
#  'District of Columbia',
#  'Florida',
#  'Georgia',
#  'Hawaii',
#  'Idaho',
#  'Illinois',
#  'Indiana',
#  'Iowa',
#  'Kansas',
#  'Kentucky',
#  'Louisiana',
#  'Maine',
#  'Maryland',
#  'Massachusetts',
#  'Michigan',
#  'Minnesota',
#  'Missouri',
#  'Montana',
#  'Nebraska',
#  'Nevada',
#  'New Hampshire',
#  'New Jersey',
#  'New Mexico',
#  'New York',
#  'North Carolina',
#  'North Dakota',
#  'Ohio',
#  'Oklahoma',
#  'Oregon',
#  'Pennsylvania',
#  'Rhode Island',
#  'South Carolina',
#  'Tennessee',
#  'Texas',
#  'Utah',
#  'Vermont',
#  'Virginia',
#  'Washington',
#  'West Virginia',
#  'Wisconsin',
#  'Wyoming',
#  'Arkansas',
#  'South Dakota',
#  'Mississippi',
#  'Puerto Rico']

# %%
# Create Cross table to compare the percentage of increase between 1999-2015 
states_cross=pd.crosstab(usa_states['States and Puerto Rico'],usa_states['Year'], aggfunc='sum', values=usa_states['Count'])
states_cross.head()
# Out:
# Year                     1,999   2,000   2,001  ...   2,013   2,014   2,015
# States and Puerto Rico                          ...
# Alabama                 19,891  20,460  21,731  ...  26,413  26,279  27,254
# Alaska                   2,043   2,128   2,269  ...   2,816   2,822   2,846
# Arizona                 21,878  22,713  23,969  ...  30,342  31,644  31,827
# Arkansas                   nan     nan  13,613  ...  16,663  16,951  17,396
# California             140,586 141,761 146,920  ... 169,449 171,495 172,776
#
# [5 rows x 17 columns]

# %%
pd.options.display.float_format = '{:,.4f}'.format
#create cross table 
states_cross['rate Incidence']= ((states_cross[2015]-states_cross[1999])/states_cross[1999])
states_cross.head()
# Out:
# Year                         1999.0       2000.0  ...       2015.0  rate Incidence
# States and Puerto Rico                            ...
# Alabama                 19,891.0000  20,460.0000  ...  27,254.0000          0.3702
# Alaska                   2,043.0000   2,128.0000  ...   2,846.0000          0.3930
# Arizona                 21,878.0000  22,713.0000  ...  31,827.0000          0.4547
# Arkansas                        nan          nan  ...  17,396.0000             nan
# California             140,586.0000 141,761.0000  ... 172,776.0000          0.2290
#
# [5 rows x 18 columns]

# %%
states_cross.sort_values(by='rate Incidence', ascending=False) #orden cross table by rate of incidence
# Out:
# Year                         1999.0       2000.0  ...       2015.0  rate Incidence
# States and Puerto Rico                            ...
# Georgia                 31,248.0000  34,031.0000  ...  51,242.0000          0.6398
# Tennessee               22,737.0000  23,800.0000  ...  37,277.0000          0.6395
# North Carolina          35,497.0000  37,555.0000  ...  56,189.0000          0.5829
# Utah                     6,815.0000   6,765.0000  ...  10,694.0000          0.5692
# Idaho                    5,371.0000   5,822.0000  ...   8,349.0000          0.5545
# Nevada                   7,714.0000   9,862.0000  ...  11,774.0000          0.5263
# Delaware                 4,128.0000   4,290.0000  ...   6,098.0000          0.4772
# South Carolina          19,387.0000  19,547.0000  ...  28,206.0000          0.4549
# Arizona                 21,878.0000  22,713.0000  ...  31,827.0000          0.4547
# Colorado                16,711.0000  17,414.0000  ...  23,335.0000          0.3964
# ...

# %%
# table with top 3 
pd.options.display.float_format = '{:,.0f}'.format
condition_states = ['Georgia','Tennessee', 'North Carolina']
top3_rate_states= usa_states[usa_states['States and Puerto Rico'].isin(condition_states)]
top3_rate_states
# Out:
#     Notes  Year  ...  States and Puerto Rico Code  Count
# 9      \t 1,999  ...                           13 31,248
# 31     \t 1,999  ...                           37 35,497
# 39     \t 1,999  ...                           47 22,737
# 57     \t 2,000  ...                           13 34,031
# 79     \t 2,000  ...                           37 37,555
# 87     \t 2,000  ...                           47 23,800
# 106    \t 2,001  ...                           13 35,658
# 128    \t 2,001  ...                           37 38,530
# 137    \t 2,001  ...                           47 24,146
# 156    \t 2,002  ...                           13 36,771
# 178    \t 2,002  ...                           37 39,181
# 187    \t 2,002  ...                           47 25,032
# 206    \t 2,003  ...                           13 37,046
# 229    \t 2,003  ...                           37 40,165
# 238    \t 2,003  ...                           47 26,771
# ...

# %%
sns.set_style("whitegrid")
#Incidence of Cancer (# of people)
plt.figure(figsize=(7,7));
ax=sns.lineplot(data=top3_rate_states,x='Year',y='Count', hue='States and Puerto Rico', palette="tab10", linewidth=2.5)
plt.suptitle('States with Higher Cancer Incidence Rate',fontsize=14,fontweight="bold",x=0.5,y=1)
sns.despine()
plt.title('1999-2015',x=0.5,y=1.06,fontsize=14)
ax.set(xlabel='Year',ylabel='Incidence of Cancer (# of people)')
ax.text(2016, 57500, '%Change', backgroundcolor="white",ha='center', va='top', weight='bold', color='orange',fontsize=10)
ax.text(1999, 36000, '*',ha='center', va='top', weight='bold', color='orange',fontsize=20)
ax.text(2014.9, 56700, '*',ha='center', va='top', weight='bold', color='orange',fontsize=22)
ax.text(2016, 56000, '58.29%', backgroundcolor="white",ha='center', va='top', weight='bold', color='orange',fontsize=10)#North Carolina
ax.text(2016, 52000, '63.98%', backgroundcolor="white",ha='center', va='top', weight='bold', color='blue',fontsize=10)#Georgia
ax.text(2016, 37000, '63.95%', backgroundcolor="white",ha='center', va='top', weight='bold', color='green',fontsize=10);#Tenesse

# %%
top3_rate_states_comp= top3_rate_states[(top3_rate_states['Year']==2015)|(top3_rate_states['Year']==1999)]
top3_rate_states_comp
# Out:
#     Notes  Year  ...  States and Puerto Rico Code  Count
# 9      \t 1,999  ...                           13 31,248
# 31     \t 1,999  ...                           37 35,497
# 39     \t 1,999  ...                           47 22,737
# 828    \t 2,015  ...                           13 51,242
# 851    \t 2,015  ...                           37 56,189
# 860    \t 2,015  ...                           47 37,277
#
# [6 rows x 6 columns]

# %%
sns.set_style("whitegrid")
ax=sns.catplot(data=top3_rate_states_comp,x='States and Puerto Rico',y='Count', hue='Year', kind="bar",aspect=0.8)
ax.fig.set_size_inches(8.5, 5.5)
ax.fig.suptitle('States with Higher Cancer Incidence Rate', fontsize=14,color='black', x=0.58, y=1.16,fontweight="bold")
ax.fig.text(x=0.5,y=1.05, s='1999 and 2015',fontsize=12);

# %%
states_cross.sort_values(by=2015, ascending=False)

# %%
# table with top 3 
pd.options.display.float_format = '{:,.0f}'.format
condition_states2 = ['California','New York', 'Florida']
top3_pop_states= usa_states[(usa_states['States and Puerto Rico'].isin(condition_states2))&((usa_states['Year']==2015)|(usa_states['Year']==1999) )]
top3_pop_states
# Out:
#     Notes  Year  ...  States and Puerto Rico Code   Count
# 3      \t 1,999  ...                            6 140,586
# 8      \t 1,999  ...                           12 102,797
# 30     \t 1,999  ...                           36  97,678
# 822    \t 2,015  ...                            6 172,776
# 827    \t 2,015  ...                           12 115,570
# 850    \t 2,015  ...                           36 116,939
#
# [6 rows x 6 columns]

# %%
plt.style.use('fivethirtyeight')
# 
ax=sns.catplot(data=top3_pop_states,x='States and Puerto Rico',y='Count', hue='Year', kind="bar")

ax.fig.set_size_inches(4.5, 4.5)
ax.fig.suptitle('Cancer Incidence Rate by States with the Most Population', fontsize=14,color='black', x=0.58, y=1.13,fontweight="bold")
ax.fig.text(x=0.5,y=1.05, s='1999 and 2015 ',fontsize=12)
ax.set(xlabel='States',ylabel='Incidence of Cancer (# of people)');

# ax.text(2016, 56000, '58.29%', backgroundcolor="white",ha='center', va='top', weight='bold', color='orange',fontsize=10)#North Carolina
# ax.text(2016, 52000, '63.98%', backgroundcolor="white",ha='center', va='top', weight='bold', color='blue',fontsize=10)#Georgia
# ax.text(2016, 37000, '63.95%', backgroundcolor="white",ha='center', va='top', weight='bold', color='green',fontsize=10)#Tenesse

# %%
ny_years=usa_states[usa_states['States and Puerto Rico']=='New York']

# %%
ny_years
# Out:
#     Notes  Year  ...  States and Puerto Rico Code   Count
# 30     \t 1,999  ...                           36  97,678
# 78     \t 2,000  ...                           36 100,603
# 127    \t 2,001  ...                           36 101,547
# 177    \t 2,002  ...                           36 102,681
# 228    \t 2,003  ...                           36 103,167
# 279    \t 2,004  ...                           36 104,167
# 330    \t 2,005  ...                           36 105,791
# 382    \t 2,006  ...                           36 109,046
# 434    \t 2,007  ...                           36 111,202
# 486    \t 2,008  ...                           36 113,262
# 538    \t 2,009  ...                           36 114,150
# 590    \t 2,010  ...                           36 111,723
# 642    \t 2,011  ...                           36 115,875
# 694    \t 2,012  ...                           36 112,732
# 746    \t 2,013  ...                           36 116,391
# ...

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(5,5))
ax=sns.lineplot(data=ny_years, x='Year',y='Count',palette="cubehelix", linewidth=2.5)
plt.suptitle('Cancer Incidence in New York',fontsize=14,fontweight="bold",x=0.5,y=0.97)
sns.despine()
ax.text(2016.5, 117800, '%Change',ha='center', va='top', weight='bold', color='blue',fontsize=8)
ax.text(2016.5, 117000, '19,72%',ha='center', va='top', weight='bold', color='blue',fontsize=10)
ax.text(2015, 117200, '*',ha='center', va='top', weight='bold', color='blue',fontsize=18)
ax.text(1999, 97900, '*',ha='center', va='top', weight='bold', color='blue',fontsize=18)
plt.title('1999-2015',x=0.5,y=1.0,fontsize=14)
# Out:
# Text(0.5, 1.0, '1999-2015')

# %% [markdown]
# # NYC DATASET

# %%
ny1999=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc1999.txt',sep='\t')
ny2000=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2000.txt',sep='\t')
ny2001=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2001.txt',sep='\t')
ny2002=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2002.txt',sep='\t')
ny2003=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2003.txt',sep='\t')
ny2004=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2004.txt',sep='\t')
ny2005=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2005.txt',sep='\t')
ny2006=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2006.txt',sep='\t')
ny2007=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2007.txt',sep='\t')
ny2008=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2008.txt',sep='\t')
ny2009=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2009.txt',sep='\t')
ny2010=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2010.txt',sep='\t')
ny2011=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2011.txt',sep='\t')
ny2012=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2012.txt',sep='\t')
ny2013=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2013.txt',sep='\t')
ny2014=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2014.txt',sep='\t')
ny2015=pd.read_csv('https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/nyc2015.txt',sep='\t')

# %%
list(ny2015.columns)
# Out:
# ['Notes',
#  'Year',
#  'Year Code',
#  'Cancer Sites',
#  'Cancer Sites Code',
#  'Sex',
#  'Sex Code',
#  'Count']

# %%
ny2015.tail()
# Out:
#                                                  Notes  Year  ...  Sex Code Count
# 247        standard groupings of primary cancer sites.   nan  ...       NaN   NaN
# 248  6. For the 2005 year, the Census Bureau estima...   nan  ...       NaN   NaN
# 249  Texas due to Hurricanes Katrina and Rita. CDC ...   nan  ...       NaN   NaN
# 250  these states, nor are these counts included in...   nan  ...       NaN   NaN
# 251  population. However, the USCS web site does in...   nan  ...       NaN   NaN
#
# [5 rows x 8 columns]

# %%
ny1999.drop(ny1999.tail(len(ny1999)-((ny1999['Notes'].values == '---').argmax())).index,inplace=True)
ny2000.drop(ny2000.tail(len(ny2000)-((ny2000['Notes'].values == '---').argmax())).index,inplace=True)
ny2001.drop(ny2001.tail(len(ny2001)-((ny2001['Notes'].values == '---').argmax())).index,inplace=True)
ny2002.drop(ny2002.tail(len(ny2002)-((ny2002['Notes'].values == '---').argmax())).index,inplace=True)
ny2003.drop(ny2003.tail(len(ny2003)-((ny2003['Notes'].values == '---').argmax())).index,inplace=True)
ny2004.drop(ny2004.tail(len(ny2004)-((ny2004['Notes'].values == '---').argmax())).index,inplace=True)
ny2005.drop(ny2005.tail(len(ny2005)-((ny2005['Notes'].values == '---').argmax())).index,inplace=True)
ny2006.drop(ny2006.tail(len(ny2006)-((ny2006['Notes'].values == '---').argmax())).index,inplace=True)
ny2007.drop(ny2007.tail(len(ny2007)-((ny2007['Notes'].values == '---').argmax())).index,inplace=True)
ny2008.drop(ny2008.tail(len(ny2008)-((ny2008['Notes'].values == '---').argmax())).index,inplace=True)
ny2009.drop(ny2009.tail(len(ny2009)-((ny2009['Notes'].values == '---').argmax())).index,inplace=True)
ny2010.drop(ny2010.tail(len(ny2010)-((ny2010['Notes'].values == '---').argmax())).index,inplace=True)
ny2011.drop(ny2011.tail(len(ny2011)-((ny2011['Notes'].values == '---').argmax())).index,inplace=True)
ny2012.drop(ny2012.tail(len(ny2012)-((ny2012['Notes'].values == '---').argmax())).index,inplace=True)
ny2013.drop(ny2013.tail(len(ny2013)-((ny2013['Notes'].values == '---').argmax())).index,inplace=True)
ny2014.drop(ny2014.tail(len(ny2014)-((ny2014['Notes'].values == '---').argmax())).index,inplace=True)
ny2015.drop(ny2015.tail(len(ny2015)-((ny2015['Notes'].values == '---').argmax())).index,inplace=True)

# %%
ny2015.tail
# Out:
# <bound method NDFrame.tail of     Notes  Year  Year Code  ...     Sex Sex Code           Count
# 0     NaN 2,015      2,015  ...  Female        F           56948
# 1     NaN 2,015      2,015  ...    Male        M           55003
# 2     NaN 2,015      2,015  ...  Female        F             808
# 3     NaN 2,015      2,015  ...    Male        M            1837
# 4     NaN 2,015      2,015  ...  Female        F              40
# 5     NaN 2,015      2,015  ...    Male        M              60
# 6     NaN 2,015      2,015  ...  Female        F             237
# 7     NaN 2,015      2,015  ...    Male        M             578
# 8     NaN 2,015      2,015  ...  Female        F             125
# 9     NaN 2,015      2,015  ...    Male        M             186
# 10    NaN 2,015      2,015  ...  Female        F              34
# 11    NaN 2,015      2,015  ...    Male        M              81
# 12    NaN 2,015      2,015  ...  Female        F             161
# ...

# %%
list_frames=[]
for n in range(1999,2016):
 list_frames.append('ny'+str(n))
list_frames
# Out:
# ['ny1999',
#  'ny2000',
#  'ny2001',
#  'ny2002',
#  'ny2003',
#  'ny2004',
#  'ny2005',
#  'ny2006',
#  'ny2007',
#  'ny2008',
#  'ny2009',
#  'ny2010',
#  'ny2011',
#  'ny2012',
#  'ny2013',
#  'ny2014',
#  'ny2015']

# %%
#Create a dataframe unique with all the years
ny_raw = pd.concat([ny1999,ny2000,ny2001,ny2002,ny2003,ny2004,ny2005,ny2006,
                    ny2007,ny2008,ny2009,ny2010,ny2011,ny2012,ny2013,ny2014,ny2015], axis=0)

# %%
ny_raw.shape
# Out:
# (3402, 8)

# %%
ny_raw.head()
# Out:
#   Notes  Year  Year Code  ...     Sex Sex Code  Count
# 0   NaN 1,999      1,999  ...  Female        F  47533
# 1   NaN 1,999      1,999  ...    Male        M  46858
# 2   NaN 1,999      1,999  ...  Female        F    605
# 3   NaN 1,999      1,999  ...    Male        M   1322
# 4   NaN 1,999      1,999  ...  Female        F     21
#
# [5 rows x 8 columns]

# %%
ny_raw['Notes'].isnull().sum()
# Out:
# 3402

# %%
ny_raw=ny_raw.drop(['Notes'],axis=1)
ny_raw.shape
# Out:
# (3402, 7)

# %%
df_ny=ny_raw

# %%
df_ny.isnull().sum()
# Out:
# Year                 0
# Year Code            0
# Cancer Sites         0
# Cancer Sites Code    0
# Sex                  0
# Sex Code             0
# Count                0
# dtype: int64

# %%
df_ny.shape
# Out:
# (3402, 7)

# %%
df_ny['Count']=df_ny['Count'].replace(to_replace='Not Applicable',value='') #change all tab by nothing

# %%
df_ny.dtypes
# Out:
# Year                 float64
# Year Code            float64
# Cancer Sites          object
# Cancer Sites Code     object
# Sex                   object
# Sex Code              object
# Count                 object
# dtype: object

# %%
df_ny['Count']=pd.to_numeric(df_ny['Count'])

# %%
df_ny.head()
# Out:
#    Year  Year Code                        Cancer Sites  ...     Sex Sex Code  Count
# 0 1,999      1,999  All Invasive Cancer Sites Combined  ...  Female        F 47,533
# 1 1,999      1,999  All Invasive Cancer Sites Combined  ...    Male        M 46,858
# 2 1,999      1,999             Oral Cavity and Pharynx  ...  Female        F    605
# 3 1,999      1,999             Oral Cavity and Pharynx  ...    Male        M  1,322
# 4 1,999      1,999                                 Lip  ...  Female        F     21
#
# [5 rows x 7 columns]

# %%
df_ny['Cancer Sites Code'].value_counts()
# Out:
# 27010-27070           34
# 21100                 34
# 20070                 34
# 21047                 34
# 21071                 34
# 21043                 34
# 35022                 34
# 20080                 34
# 21080                 34
# 21010-21130           34
# 31040                 34
# 22010-22060           34
# 27020                 34
# 21045                 34
# 28030                 34
# 35013                 34
# 31010                 34
# 29020                 34
# 21048                 34
# 21030                 34
# 33011-33042           34
# 35012                 34
# 32010                 34
# 32010-32020           34
# 20010                 34
# 25010                 34
# 21051                 34
# 35041-35043           34
# 22020                 34
# 30000                 34
#                       ..
# 31010-31040           34
# 29030                 34
# 35021                 34
# 21020                 34
# 20010-20100           34
# 21072                 34
# ...

# %%
df_ny['Cancer Sites'].value_counts()
# Out:
# Male Genital System                                  34
# Splenic Flexure                                      34
# Liver                                                34
# Hodgkin Lymphoma                                     34
# Colon and Rectum                                     34
# Male and Female Breast                               34
# Vagina                                               34
# Other Endocrine including Thymus                     34
# Miscellaneous                                        34
# Respiratory System                                   34
# Nose, Nasal Cavity and Middle Ear                    34
# Other Non-Epithelial Skin                            34
# Oral Cavity and Pharynx                              34
# Tongue                                               34
# Ovary                                                34
# Non-Hodgkin Lymphoma                                 34
# NHL - Extranodal                                     34
# ...

# %%
categories=['20010-20100','21010-21130','22010-22060','23000','24000','25010-25020','27010-27070','26000-Female','26000-Male',
            '28010-28040','29010-29040','30000','31010-31040','32010-32020','33011-33042','34000','35011-35043',
            '36010','36020','37000']

# %%
ny_categories=df_ny[df_ny['Cancer Sites Code'].isin(categories)]
ny_categories=ny_categories.replace('Not Applicable','')
ny_categories
# Out:
#      Year  Year Code                       Cancer Sites  ...     Sex Sex Code  Count
# 2   1,999      1,999            Oral Cavity and Pharynx  ...  Female        F    605
# 3   1,999      1,999            Oral Cavity and Pharynx  ...    Male        M  1,322
# 24  1,999      1,999                   Digestive System  ...  Female        F  9,677
# 25  1,999      1,999                   Digestive System  ...    Male        M 10,106
# 79  1,999      1,999                 Respiratory System  ...  Female        F  6,120
# 80  1,999      1,999                 Respiratory System  ...    Male        M  7,625
# 88  1,999      1,999                   Bones and Joints  ...  Female        F    107
# 89  1,999      1,999                   Bones and Joints  ...    Male        M    101
# 90  1,999      1,999        Soft Tissue including Heart  ...  Female        F    284
# 91  1,999      1,999        Soft Tissue including Heart  ...    Male        M    279
# ...

# %%
group_categories=ny_categories.groupby(['Cancer Sites','Year']).sum()
group_categories
# Out:
#                                       Year Code  Count
# Cancer Sites                   Year
# Bones and Joints               1,999      3,998    208
#                                2,000      4,000    211
#                                2,001      4,002    230
#                                2,002      4,004    225
#                                2,003      4,006    215
#                                2,004      4,008    229
#                                2,005      4,010    210
#                                2,006      4,012    222
#                                2,007      4,014    207
#                                2,008      4,016    193
#                                2,009      4,018    207
#                                2,010      4,020    186
#                                2,011      4,022    196
#                                2,012      4,024    214
#                                2,013      4,026    211
# ...

# %%
cat_2015_1999=ny_categories[(ny_categories['Year']==1999)|(ny_categories['Year']==2015)]
cat_2015_1999
# Out:
#      Year  Year Code                       Cancer Sites  ...     Sex Sex Code  Count
# 2   1,999      1,999            Oral Cavity and Pharynx  ...  Female        F    605
# 3   1,999      1,999            Oral Cavity and Pharynx  ...    Male        M  1,322
# 24  1,999      1,999                   Digestive System  ...  Female        F  9,677
# 25  1,999      1,999                   Digestive System  ...    Male        M 10,106
# 79  1,999      1,999                 Respiratory System  ...  Female        F  6,120
# 80  1,999      1,999                 Respiratory System  ...    Male        M  7,625
# 88  1,999      1,999                   Bones and Joints  ...  Female        F    107
# 89  1,999      1,999                   Bones and Joints  ...    Male        M    101
# 90  1,999      1,999        Soft Tissue including Heart  ...  Female        F    284
# 91  1,999      1,999        Soft Tissue including Heart  ...    Male        M    279
# ...

# %%
test_ny=cat_2015_1999[(cat_2015_1999['Cancer Sites']=='Digestive System')]
test_ny.head(50)
# Out:
#     Year  Year Code      Cancer Sites Cancer Sites Code     Sex Sex Code  Count
# 24 1,999      1,999  Digestive System       21010-21130  Female        F  9,677
# 25 1,999      1,999  Digestive System       21010-21130    Male        M 10,106
# 23 2,015      2,015  Digestive System       21010-21130  Female        F  9,072
# 24 2,015      2,015  Digestive System       21010-21130    Male        M 10,700

# %%
cross_cat=pd.crosstab(index=cat_2015_1999['Cancer Sites'],columns=cat_2015_1999['Year'],aggfunc='sum',values=cat_2015_1999['Count'])
cross_cat
# Out:
# Year                               1,999  2,015
# Cancer Sites
# Bones and Joints                     208    217
# Brain and Other Nervous System     1,308  1,415
# Digestive System                  19,783 19,772
# Endocrine System                   1,668  4,507
# Eye and Orbit                        177    210
# Female Breast                     14,201 16,359
# Female Genital System              6,010  7,125
# Kaposi Sarcoma                       199    145
# Leukemias                          2,669  3,624
# Lymphomas                          4,530  5,519
# Male Breast                          105    192
# Male Genital System               14,436 14,307
# Mesothelioma                         198    200
# Miscellaneous                      2,035  4,186
# Myeloma                            1,247  1,803
# Oral Cavity and Pharynx            1,927  2,645
# Respiratory System                13,745 14,999
# Skin excluding Basal and Squamous  2,141  4,489
# ...

# %%
top5_cancer_nyc= cross_cat.nlargest(5, 2015)
top5_cancer_nyc
# Out:
# Year                 1,999  2,015
# Cancer Sites
# Digestive System    19,783 19,772
# Female Breast       14,201 16,359
# Respiratory System  13,745 14,999
# Male Genital System 14,436 14,307
# Urinary System       7,241  9,472

# %%
cross_cat[2015].sum()
# Out:
# 111951.0

# %%
top5=['Digestive System','Female Breast','Respiratory System','Male Genital System','Urinary System']

# %%
top5_types=df_ny[df_ny['Cancer Sites'].isin(top5)]
top5_types.head(20)
# Out:
#      Year  Year Code         Cancer Sites  ...     Sex Sex Code  Count
# 24  1,999      1,999     Digestive System  ...  Female        F  9,677
# 25  1,999      1,999     Digestive System  ...    Male        M 10,106
# 79  1,999      1,999   Respiratory System  ...  Female        F  6,120
# 80  1,999      1,999   Respiratory System  ...    Male        M  7,625
# 100 1,999      1,999        Female Breast  ...  Female        F 14,201
# 101 1,999      1,999        Female Breast  ...    Male        M    nan
# 120 1,999      1,999  Male Genital System  ...  Female        F    nan
# 121 1,999      1,999  Male Genital System  ...    Male        M 14,436
# 130 1,999      1,999       Urinary System  ...  Female        F  2,359
# 131 1,999      1,999       Urinary System  ...    Male        M  4,882
# 24  2,000      2,000     Digestive System  ...  Female        F  9,800
# 25  2,000      2,000     Digestive System  ...    Male        M 10,094
# ...

# %%
top5_types_years = pd.pivot_table(top5_types, values='Count', index='Year', columns=['Cancer Sites'], aggfunc='sum', fill_value=0)
top5_types_years.head(20)
# Out:
# Cancer Sites  Digestive System  ...  Urinary System
# Year                            ...
# 1,999                    19783  ...            7241
# 2,000                    19894  ...            7350
# 2,001                    19515  ...            7440
# 2,002                    19467  ...            7558
# 2,003                    19687  ...            7885
# 2,004                    19545  ...            8271
# 2,005                    19367  ...            8335
# 2,006                    19201  ...            8504
# 2,007                    19558  ...            8638
# 2,008                    19494  ...            8875
# 2,009                    19192  ...            8763
# 2,010                    19068  ...            8606
# 2,011                    19125  ...            9049
# 2,012                    18912  ...            9206
# 2,013                    19742  ...            9363
# 2,014                    19782  ...            9346
# ...

# %%
top5_types_years.reset_index(inplace=True)
top5_types_years
# Out:
# Cancer Sites  Year  Digestive System  ...  Respiratory System  Urinary System
# 0            1,999             19783  ...               13745            7241
# 1            2,000             19894  ...               14121            7350
# 2            2,001             19515  ...               13805            7440
# 3            2,002             19467  ...               14025            7558
# 4            2,003             19687  ...               14052            7885
# 5            2,004             19545  ...               14126            8271
# 6            2,005             19367  ...               14199            8335
# 7            2,006             19201  ...               14364            8504
# 8            2,007             19558  ...               14526            8638
# 9            2,008             19494  ...               14844            8875
# 10           2,009             19192  ...               14695            8763
# ...

# %%
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scatter(x=top5_types_years['Year'], y=top5_types_years['Digestive System'],
                    mode='lines',
                     name='Digestive System'))
fig.add_trace(go.Scatter(x=top5_types_years['Year'], y=top5_types_years['Female Breast'],
                    mode='lines',
                     name='Female Breast'))
fig.add_trace(go.Scatter(x=top5_types_years['Year'], y=top5_types_years['Male Genital System'],
                    mode='lines',
                     name='Male Genital System'))
fig.add_trace(go.Scatter(x=top5_types_years['Year'], y=top5_types_years['Respiratory System'],
                    mode='lines',
                     name='Respiratory System'))
fig.add_trace(go.Scatter(x=top5_types_years['Year'], y=top5_types_years['Urinary System'],
                    mode='lines',
                     name='Urinary System'))

fig.update_layout(title='Highest Incidence Cancer Types in New York',
                   xaxis_title='Year',
                   yaxis_title='Incidence of Cancer')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6e23cbf6-7a12-4746-8eb6-b0107b014ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6e23cbf6-7a12-4746-8eb6-b0107b014ad9")) {
#                     Plotly.newPlot(
#                         '6e23cbf6-7a12-4746-8eb6-b0107b014ad9',
# ...

# %%
plt.style.use('fivethirtyeight')
# 
ax=sns.catplot(data=top5_types_19992015,x='Cancer Sites',y='Count', kind="bar",hue='Year',ci=None)
ax.set_xticklabels(rotation=30)
ax.fig.set_size_inches(9.5, 9.5)
ax.fig.suptitle('Highest Incidence Cancer Types in New York', fontsize=14,color='black', x=0.58, y=1.01,fontweight="bold")
ax.fig.text(x=0.45,y=0.95, s='1999 and 2015', fontweight="bold",fontsize=12)

# %%
#Conclusion los canceres con mayor incidencia no han cambiado

# %%
dig_syst=df_ny[df_ny['Cancer Sites']=='Digestive System']
dig_syst
# Out:
#     Year  Year Code      Cancer Sites Cancer Sites Code     Sex Sex Code  Count
# 24 1,999      1,999  Digestive System       21010-21130  Female        F  9,677
# 25 1,999      1,999  Digestive System       21010-21130    Male        M 10,106
# 24 2,000      2,000  Digestive System       21010-21130  Female        F  9,800
# 25 2,000      2,000  Digestive System       21010-21130    Male        M 10,094
# 23 2,001      2,001  Digestive System       21010-21130  Female        F  9,479
# 24 2,001      2,001  Digestive System       21010-21130    Male        M 10,036
# 24 2,002      2,002  Digestive System       21010-21130  Female        F  9,412
# 25 2,002      2,002  Digestive System       21010-21130    Male        M 10,055
# 24 2,003      2,003  Digestive System       21010-21130  Female        F  9,530
# 25 2,003      2,003  Digestive System       21010-21130    Male        M 10,157
# 24 2,004      2,004  Digestive System       21010-21130  Female        F  9,515
# ...

# %%
dig_syst_2015=dig_syst[dig_syst['Year']==2015]
dig_syst_2015
# Out:
#     Year  Year Code      Cancer Sites Cancer Sites Code     Sex Sex Code  Count
# 23 2,015      2,015  Digestive System       21010-21130  Female        F  9,072
# 24 2,015      2,015  Digestive System       21010-21130    Male        M 10,700

# %% [markdown]
# # T_test
# H0: women

# %%
url_pop='https://raw.githubusercontent.com/johanaluna/Cancer_DataSet/master/PEP_2018_PEPANNRES.csv'

# %%
population=pd.read_csv(url_pop)
population.head(10)
# Out:
#         GEO.id  GEO.id2  ... respop72017  respop72018
# 0    0100000US      nan  ...   325147121    327167434
# 1   0200000US1   1.0000  ...    56072676     56111079
# 2   0200000US2   2.0000  ...    68156035     68308744
# 3   0200000US3   3.0000  ...   123598424    124753948
# 4   0200000US4   4.0000  ...    77319986     77993663
# 5  0400000US01   1.0000  ...     4875120      4887871
# 6  0400000US02   2.0000  ...      739786       737438
# 7  0400000US04   4.0000  ...     7048876      7171646
# 8  0400000US05   5.0000  ...     3002997      3013825
# 9  0400000US06   6.0000  ...    39399349     39557045
#
# [10 rows x 14 columns]

# %%
population_2015=population[['GEO.display-label','respop72015']]

population_2015=population_2015.drop(population_2015.index[[0,1,2,3,4]],axis=0)

# %%
population_2015.head(10)
# Out:
#        GEO.display-label  respop72015
# 5                Alabama      4853160
# 6                 Alaska       737547
# 7                Arizona      6833596
# 8               Arkansas      2978407
# 9             California     38953142
# 10              Colorado      5452107
# 11           Connecticut      3587509
# 12              Delaware       941413
# 13  District of Columbia       675254
# 14               Florida     20224249

# %%
totalp=population_2015['respop72015'].sum()
pd.options.display.float_format = '{:,.4f}'.format

# %%
population_2015['% of Total US']=(population_2015['respop72015']/totalp)
population_2015['% of Total US']=population_2015['% of Total US'].astype(float).round(4)
population_2015.head()
# Out:
#   GEO.display-label  respop72015  % of Total US
# 5           Alabama      4853160           0.01
# 6            Alaska       737547           0.00
# 7           Arizona      6833596           0.02
# 8          Arkansas      2978407           0.01
# 9        California     38953142           0.12

# %%
len(population_2015['GEO.display-label'].unique())
# Out:
# 52

# %%
mean_population=population_2015['respop72015'].mean()
mean_population
# Out:
# 6234919.980769231

# %%
top5_pop=population_2015.nlargest(5,columns='respop72015')
top5_pop
# Out:
#    GEO.display-label  respop72015
# 9         California     38953142
# 48             Texas     27486814
# 14           Florida     20224249
# 37          New York     19661411
# 18          Illinois     12864342

# %%
usa_states.head()
# Out:
#   Notes       Year  ...  States and Puerto Rico Code        Count
# 0    \t 1,999.0000  ...                       1.0000  19,891.0000
# 1    \t 1,999.0000  ...                       2.0000   2,043.0000
# 2    \t 1,999.0000  ...                       4.0000  21,878.0000
# 3    \t 1,999.0000  ...                       6.0000 140,586.0000
# 4    \t 1,999.0000  ...                       8.0000  16,711.0000
#
# [5 rows x 6 columns]

# %%
usa_states_2015=usa_states[usa_states['Year']==2015]
usa_states_2015
# Out:
#     Notes       Year  ...  States and Puerto Rico Code        Count
# 818    \t 2,015.0000  ...                       1.0000  27,254.0000
# 819    \t 2,015.0000  ...                       2.0000   2,846.0000
# 820    \t 2,015.0000  ...                       4.0000  31,827.0000
# 821    \t 2,015.0000  ...                       5.0000  17,396.0000
# 822    \t 2,015.0000  ...                       6.0000 172,776.0000
# 823    \t 2,015.0000  ...                       8.0000  23,335.0000
# 824    \t 2,015.0000  ...                       9.0000  21,762.0000
# 825    \t 2,015.0000  ...                      10.0000   6,098.0000
# 826    \t 2,015.0000  ...                      11.0000   2,619.0000
# 827    \t 2,015.0000  ...                      12.0000 115,570.0000
# 828    \t 2,015.0000  ...                      13.0000  51,242.0000
# 829    \t 2,015.0000  ...                      15.0000   7,435.0000
# 830    \t 2,015.0000  ...                      16.0000   8,349.0000
# ...

# %%
mean_usa_states_2015=usa_states_2015['Count'].mean()

# %%
mean_usa_states_2015
# Out:
# 32829.519230769234

# %%
import numpy as np
from scipy import stats
import numpy as np

# %%
usa_states_2015['Count']
# Out:
# 818    27,254.0000
# 819     2,846.0000
# 820    31,827.0000
# 821    17,396.0000
# 822   172,776.0000
# 823    23,335.0000
# 824    21,762.0000
# 825     6,098.0000
# 826     2,619.0000
# 827   115,570.0000
# 828    51,242.0000
# 829     7,435.0000
# 830     8,349.0000
# 831    71,012.0000
# 832    35,070.0000
# 833    18,406.0000
# 834    15,435.0000
# 835    27,643.0000
# 836    25,899.0000
# 837     8,970.0000
# 838    32,063.0000
# 839    38,562.0000
# 840    55,058.0000
# 841    31,223.0000
# 842    16,254.0000
# 843    33,958.0000
# 844     6,087.0000
# 845    10,161.0000
# 846    11,774.0000
# 847     8,278.0000
# 848    53,317.0000
# 849     9,341.0000
# 850   116,939.0000
# 851    56,189.0000
# 852     3,849.0000
# 853    67,610.0000
# 854    20,306.0000
# 855    20,467.0000
# 856    82,025.0000
# 857     6,170.0000
# 858    28,206.0000
# 859     4,535.0000
# 860    37,277.0000
# 861   110,700.0000
# 862    10,694.0000
# 863     3,746.0000
# 864    40,044.0000
# ...

# %%
#compare 1 depend variable with mean population
#* H0: The cancer mean is equal to the population mean in United States
#* H1: The cancer mean is not equal to the population mean in United States

result2= ttest_1samp(usa_states_2015['Count'],mean_population, nan_policy='omit') #
print('t-statistic:',result2[0], ' p-value:', result2[1])
if result2[1] < 0.05:
  print('\n  We reject the null hypothesis.The cancer mean is not equal to the population mean in United States ')
else:
  print('The null hypothesis is correct. The cancer mean is equal to the population mean in United States ')
# Out:
# t-statistic: -1296.176615149052  p-value: 6.96406155093386e-117
#
#   We reject the null hypothesis.The cancer mean is not equal to the population mean in United States
